# %%
import json_helper as jh
import pandas as pd

# %%
# use json_helper to load all json objects into a dataframe called df_daily_summaries
contents = jh.read_all_json_files('data/daily_summaries')
df = pd.DataFrame(contents)

# %%
# display a summary of df_daily_summaries
df.head(10)
# Out:
#                   date datatype            station attributes  value
# 0  2018-01-01T00:00:00     PRCP  GHCND:US1DENC0001   ,,N,0700      0
# 1  2018-01-01T00:00:00     SNWD  GHCND:US1DENC0001  T,,N,0700      0
# 2  2018-01-01T00:00:00     PRCP  GHCND:US1DENC0002   ,,N,0700      0
# 3  2018-01-01T00:00:00     SNOW  GHCND:US1DENC0002   ,,N,0700      0
# 4  2018-01-01T00:00:00     SNWD  GHCND:US1DENC0002  T,,N,0700      0
# 5  2018-01-01T00:00:00     WESD  GHCND:US1DENC0002  T,,N,0700      0
# 6  2018-01-01T00:00:00     WESF  GHCND:US1DENC0002   ,,N,0700      0
# 7  2018-01-01T00:00:00     PRCP  GHCND:US1DENC0004   ,,N,0700      0
# 8  2018-01-01T00:00:00     SNOW  GHCND:US1DENC0004   ,,N,0700      0
# 9  2018-01-01T00:00:00     PRCP  GHCND:US1DENC0010  T,,N,0600      0

# %% [markdown]
# How many stations are there in total for FIPS10003

# %%
df['station'].nunique()
# Out:
# 17

# %% [markdown]
# Create a DataFrame called temps_max that only contains the entries from df_daily_summaries where the datatype column is equal to TMAX. This DataFrame should only retain the date column and the value column.

# %%
temps_max = df.loc[(df['datatype'] == 'TMAX')]
temps_max = temps_max.iloc[:,[0,4]]

# %%
temps_max
# Out:
#                      date  value
# 42    2018-01-01T00:00:00    -60
# 89    2018-01-02T00:00:00    -38
# 138   2018-01-03T00:00:00     -5
# 193   2018-01-04T00:00:00    -21
# 240   2018-01-05T00:00:00    -82
# 279   2018-01-06T00:00:00    -88
# 322   2018-01-07T00:00:00    -71
# 365   2018-01-08T00:00:00      6
# 399   2018-01-09T00:00:00     78
# 443   2018-01-10T00:00:00     56
# 488   2018-01-11T00:00:00    133
# 529   2018-01-12T00:00:00    167
# 577   2018-01-13T00:00:00    139
# 621   2018-01-14T00:00:00    -32
# 670   2018-01-15T00:00:00      0
# 720   2018-01-16T00:00:00     56
# 773   2018-01-17T00:00:00     22
# 819   2018-01-18T00:00:00     22
# 864   2018-01-19T00:00:00     83
# 908   2018-01-20T00:00:00    139
# 955   2018-01-21T00:00:00    117
# 993   2018-01-22T00:00:00    156
# 1033  2018-01-23T00:00:00    172
# 1076  2018-01-24T00:00:00     72
# 1119  2018-01-25T00:00:00     28
# 1163  2018-01-26T00:00:00     39
# 1206  2018-01-27T00:00:00    150
# 1242  2018-01-28T00:00:00    133
# 1291  2018-01-29T00:00:00     78
# 1334  2018-01-30T00:00:00     39
# 1380  2018-01-31T00:00:00      6

# %% [markdown]
# How many entries are there in the temps_max DataFrame? What are the mean, min, and max values?

# %%
temps_max.describe()
# Out:
#             value
# count   31.000000
# mean    48.193548
# std     77.768640
# min    -88.000000
# 25%     -2.500000
# 50%     39.000000
# 75%    125.000000
# max    172.000000

# %% [markdown]
# Let's graph this DataFrame so we can get a visual representation for this information.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = temps_max['date'].str[8:10]
y = temps_max['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Max Temperatues Jan 2018')
# Out:
# [Text(0.5, 0, 'day of month'),
#  Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 1.0, 'Max Temperatues Jan 2018')]

# %% [markdown]
# Create a DataFrame called temps_min that only contains the entries from df_daily_summaries where the datatype column is equal to TMIN. This DataFrame should only retain the date column and the value column.

# %%
temps_min = df.loc[(df['datatype'] == 'TMIN')]
temps_min = temps_min.iloc[:,[0,4]]

# %%
temps_min
# Out:
#                      date  value
# 43    2018-01-01T00:00:00   -149
# 90    2018-01-02T00:00:00   -116
# 139   2018-01-03T00:00:00   -132
# 194   2018-01-04T00:00:00    -93
# 241   2018-01-05T00:00:00   -121
# 280   2018-01-06T00:00:00   -138
# 323   2018-01-07T00:00:00   -166
# 366   2018-01-08T00:00:00   -105
# 400   2018-01-09T00:00:00    -60
# 444   2018-01-10T00:00:00    -49
# 489   2018-01-11T00:00:00     33
# 530   2018-01-12T00:00:00     83
# 578   2018-01-13T00:00:00    -71
# 622   2018-01-14T00:00:00   -105
# 671   2018-01-15T00:00:00    -88
# 721   2018-01-16T00:00:00    -16
# 774   2018-01-17T00:00:00    -77
# 820   2018-01-18T00:00:00    -99
# 865   2018-01-19T00:00:00    -66
# 909   2018-01-20T00:00:00    -38
# 956   2018-01-21T00:00:00    -32
# 994   2018-01-22T00:00:00     39
# 1034  2018-01-23T00:00:00     44
# 1077  2018-01-24T00:00:00      6
# 1120  2018-01-25T00:00:00    -38
# 1164  2018-01-26T00:00:00    -66
# 1207  2018-01-27T00:00:00    -49
# 1243  2018-01-28T00:00:00     72
# 1292  2018-01-29T00:00:00     33
# 1335  2018-01-30T00:00:00    -55
# 1381  2018-01-31T00:00:00    -93

# %% [markdown]
# How many entries are there in the temps_min DataFrame? What are the mean, min, and max values?

# %%
temps_min.describe()
# Out:
#             value
# count   31.000000
# mean   -55.225806
# std     65.749378
# min   -166.000000
# 25%   -102.000000
# 50%    -66.000000
# 75%    -24.000000
# max     83.000000

# %% [markdown]
# Graph the temps_min DataFrame

# %%
x = temps_min['date'].str[8:10]
y = temps_min['value'] / 10

# %% [markdown]
# We can also plot both of these lines in the same graph.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, temps_max['value'] / 10, color='red')
ax.plot(x, temps_min['value'] / 10, color='blue')
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min & Max Temperatues Jan 2018')
# Out:
# [Text(0.5, 0, 'day of month'),
#  Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 1.0, 'Min & Max Temperatues Jan 2018')]
